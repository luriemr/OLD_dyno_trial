# %%
import pandas as pd

# %%
import sqlite3

# %%
dyno = pd.read_csv('/Users/mr_lurie/Documents/GitHub/data/files/values.csv')

# %%
dyno.head(75)
# Out:
#                  player   pos team   age  draft_year  ecr_1qb  ecr_2qb  \
# 0   Christian McCaffrey    RB  CAR  24.0      2017.0     1.10     1.10
# 1        Saquon Barkley    RB  NYG  23.3      2018.0     2.10     2.50
# 2        Michael Thomas    WR  NOS  27.2      2016.0     3.00     3.40
# 3       Ezekiel Elliott    RB  DAL  24.9      2016.0     5.20     6.70
# 4          Alvin Kamara    RB  NOS  23.9      2017.0     6.50     8.50
# ..                  ...   ...  ...   ...         ...      ...      ...
# 70         Jalen Reagor    WR  PHI  21.4      2020.0    64.10    88.80
# 71       DeVante Parker    WR  MIA  27.4      2015.0    65.20    90.20
# 72     Justin Jefferson    WR  MIN  21.0      2020.0    65.30    90.40
# 73       2020 Pick 1.07  PICK  NaN   NaN         NaN    67.05    75.35
# 74          LeVeon Bell    RB  NYJ  28.3      2013.0    67.90    88.20
#
#     ecr_pos  value_1qb  value_2qb scrape_date    fp_id
# 0       1.0      10232      10240  2020-05-21  16393.0
# ...

# %%
dyno.loc[0, :]
# Out:
# player         Christian McCaffrey
# pos                             RB
# team                           CAR
# age                             24
# draft_year                    2017
# ecr_1qb                        1.1
# ecr_2qb                        1.1
# ecr_pos                          1
# value_1qb                    10232
# value_2qb                    10240
# scrape_date             2020-05-21
# fp_id                        16393
# Name: 0, dtype: object

# %%
dyno.loc[0:30, :]
# Out:
#                    player   pos team   age  draft_year  ecr_1qb  ecr_2qb  \
# 0     Christian McCaffrey    RB  CAR  24.0      2017.0     1.10     1.10
# 1          Saquon Barkley    RB  NYG  23.3      2018.0     2.10     2.50
# 2          Michael Thomas    WR  NOS  27.2      2016.0     3.00     3.40
# 3         Ezekiel Elliott    RB  DAL  24.9      2016.0     5.20     6.70
# 4            Alvin Kamara    RB  NOS  23.9      2017.0     6.50     8.50
# 5         DeAndre Hopkins    WR  ARI  28.0      2013.0     6.50     8.20
# 6             Dalvin Cook    RB  MIN  24.8      2017.0     6.60     8.70
# 7           Davante Adams    WR  GBP  27.4      2014.0     8.70    11.30
# 8             Tyreek Hill    WR  KCC  26.2      2016.0     9.10    11.80
# 9            Chris Godwin    WR  TBB  24.3      2017.0    10.30    13.50
# 10              Joe Mixon    RB  CIN  23.8      2017.0    13.00    17.50
# 11             Mike Evans    WR  TBB  26.8      2014.0    14.00    18.60
# ...

# %%
dyno[dyno.player=='Alvin Kamara', dyno.player=='Miles Sanders']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-0dc9a798c37c> in <module>
# ----> 1 dyno[dyno.player=='Alvin Kamara', dyno.player=='Miles Sanders']
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2644                 )
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#    2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# ...

# %%
dyno[dyno.player==('Alvin Kamara''Miles Sanders')]
# Out:
# Empty DataFrame
# Columns: [player, pos, team, age, draft_year, ecr_1qb, ecr_2qb, ecr_pos, value_1qb, value_2qb, scrape_date, fp_id]
# Index: []

# %%
dyno[dyno.player=='Alvin Kamara']
# Out:
#          player pos team   age  draft_year  ecr_1qb  ecr_2qb  ecr_pos  \
# 4  Alvin Kamara  RB  NOS  23.9      2017.0      6.5      8.5      4.2
#
#    value_1qb  value_2qb scrape_date    fp_id
# 4       9013       8589  2020-05-21  16421.0

# %%
dyno.loc[dyno.player=="Alvin Kamara"]
# Out:
#          player pos team   age  draft_year  ecr_1qb  ecr_2qb  ecr_pos  \
# 4  Alvin Kamara  RB  NOS  23.9      2017.0      6.5      8.5      4.2
#
#    value_1qb  value_2qb scrape_date    fp_id
# 4       9013       8589  2020-05-21  16421.0

# %%
dyno.loc[(dyno.player=='Alvin Kamara') | (dyno.player=='Julio Jones') | (dyno.player=='Patrick Mahomes') | (dyno.player=='Clyde Edwards-Helaire') | (dyno.player=='Odell Beckham Jr.') | (dyno.player=='Allen Robinson') | (dyno.player=='Evan Engram') | (dyno.player=='Marquise Brown') | (dyno.player=='LeVeon Bell') | (dyno.player=='Mecole Hardman') | (dyno.player=='Justin Jefferson') | (dyno.player=='Hayden Hurst') | (dyno.player=='Rob Gronkowski') | (dyno.player=='Sterling Shepard') | (dyno.player=='Antonio Brown') | (dyno.player=='Tony Pollard') | (dyno.player=='Damien Harris')]
# Out:
#                     player pos team   age  draft_year  ecr_1qb  ecr_2qb  \
# 4             Alvin Kamara  RB  NOS  23.9      2017.0      6.5      8.5
# 19       Odell Beckham Jr.  WR  CLE  27.6      2014.0     21.8     29.6
# 24   Clyde Edwards-Helaire  RB  KCC  21.1      2020.0     25.6     34.9
# 26             Julio Jones  WR  ATL  31.3      2011.0     28.8     39.6
# 31         Patrick Mahomes  QB  KCC  24.7      2017.0     31.4      5.9
# 37          Allen Robinson  WR  CHI  26.8      2014.0     36.6     50.9
# 63             Evan Engram  TE  NYG  25.7      2017.0     59.7     73.9
# 72        Justin Jefferson  WR  MIN  21.0      2020.0     65.3     90.4
# 74             LeVeon Bell  RB  NYJ  28.3      2013.0     67.9     88.2
# 81          Marquise Brown  WR  BAL  23.0      2019.0     72.6     99.4
# 112         Mecole Hardman  WR  KCC  22.2      2019.0    100.2    130.2
# 138       Sterling Shepard  WR  NYG  27.3      2016.0    120.2    150.3
# ...
